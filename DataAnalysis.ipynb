# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path
import zipfile
import io
import pyarrow.parquet as pq
import pyarrow as pa

# %%
def read_zip_csv(zip_path: Path) -> pl.LazyFrame:
    """Read the CSV inside a zip into a Polars LazyFrame."""
    with zipfile.ZipFile(zip_path) as zf:
        csv_name = [f for f in zf.namelist() if f.endswith(".csv")][0]
        with zf.open(csv_name) as f:
            raw = f.read()
    return pl.read_csv(
        io.BytesIO(raw),
        infer_schema_length=1000,
        null_values=["", "NA", "null", "NULL"],
    )

df = read_zip_csv(Path('data/raw/aisdk-2025-06-01.zip'))
df = df.filter(pl.col("Ship type").is_in(["Cargo", "Tanker", "Fishing", "Tug", "Passenger"]))

# %%
# --- Configuration ---
class_column = "Ship type"  # <-- change to your column name
df_subset = df.select(["Cargo type","Width","Length", "Draught", "Type of mobile", "Ship type", "SOG"])[:100000]  # Convert Polars DataFrame to Pandas DataFrame for Seaborn compatibility
pddf = df_subset.to_pandas()
palette = {
    "Cargo": "#534AB7",  # purple
    "Tanker": "#1D9E75",  # teal
    "Fishing": "#D85A30",  # coral
    "Tug": "#378ADD",  # blue
    "Passenger": "#D4537E",  # pink
}

g = sns.PairGrid(pddf, hue=class_column, palette=palette)
g.map_offdiag(sns.scatterplot, alpha=0.7, edgecolor="none", s=30)
g.map_diag(sns.histplot, alpha=0.5)
g.add_legend(title=class_column, bbox_to_anchor=(1.05, 0.5), loc="center left")

plt.suptitle("Pairplot by class", y=1.02, fontsize=14)
plt.tight_layout()
plt.show()

# %%
df[:10]
# Out:
# shape: (10, 26)
# ┌─────────────────────┬────────────────┬───────────┬───────────┬───┬─────┬─────┬─────┬─────┐
# │ # Timestamp         ┆ Type of mobile ┆ MMSI      ┆ Latitude  ┆ … ┆ A   ┆ B   ┆ C   ┆ D   │
# │ ---                 ┆ ---            ┆ ---       ┆ ---       ┆   ┆ --- ┆ --- ┆ --- ┆ --- │
# │ str                 ┆ str            ┆ i64       ┆ f64       ┆   ┆ i64 ┆ i64 ┆ i64 ┆ i64 │
# ╞═════════════════════╪════════════════╪═══════════╪═══════════╪═══╪═════╪═════╪═════╪═════╡
# │ 01/06/2025 00:00:00 ┆ Class A        ┆ 211452000 ┆ 91.0      ┆ … ┆ 20  ┆ 3   ┆ 3   ┆ 3   │
# │ 01/06/2025 00:00:00 ┆ Class A        ┆ 211452000 ┆ 91.0      ┆ … ┆ 20  ┆ 3   ┆ 3   ┆ 3   │
# │ 01/06/2025 00:00:00 ┆ Class A        ┆ 265572330 ┆ 91.0      ┆ … ┆ 11  ┆ 16  ┆ 3   ┆ 4   │
# │ 01/06/2025 00:00:00 ┆ Class A        ┆ 246389000 ┆ 91.0      ┆ … ┆ 5   ┆ 10  ┆ 2   ┆ 3   │
# │ 01/06/2025 00:00:00 ┆ Class B        ┆ 219005662 ┆ 55.512945 ┆ … ┆ 3   ┆ 8   ┆ 2   ┆ 2   │
# │ 01/06/2025 00:00:01 ┆ Class B        ┆ 219006164 ┆ 91.0      ┆ … ┆ 6   ┆ 2   ┆ 2   ┆ 1   │
# │ 01/06/2025 00:00:01 ┆ Class A        ┆ 257084120 ┆ 91.0      ┆ … ┆ 105 ┆ 24  ┆ 3   ┆ 17  │
# │ 01/06/2025 00:00:01 ┆ Class A        ┆ 257084120 ┆ 91.0      ┆ … ┆ 105 ┆ 24  ┆ 3   ┆ 17  │
# │ 01/06/2025 00:00:01 ┆ Class A        ┆ 247312900 ┆ 54.776417 ┆ … ┆ 46  ┆ 207 ┆ 19  ┆ 19  │
# │ 01/06/2025 00:00:01 ┆ Class A        ┆ 247312900 ┆ 54.776417 ┆ … ┆ 46  ┆ 207 ┆ 19  ┆ 19  │
# └─────────────────────┴────────────────┴───────────┴───────────┴───┴─────┴─────┴─────┴─────┘

# %%
#get count of rows per vessel
vessel_counts = (
    df.group_by(["MMSI"])
      .agg(pl.len().alias("row_count"))
      .sort("row_count", descending=True)
)

print(vessel_counts)

plt.figure(figsize=(10, 5))
plt.hist(vessel_counts["row_count"].to_numpy(), bins=10000, edgecolor="black")
plt.xlabel("Number of rows per vessel")
plt.ylabel("Number of vessels")
plt.title("Distribution of AIS pings per vessel (2024-06-04)")
plt.tight_layout()
plt.show()
# Out:
# shape: (2_029, 2)
# ┌───────────┬───────────┐
# │ MMSI      ┆ row_count │
# │ ---       ┆ ---       │
# │ i64       ┆ u32       │
# ╞═══════════╪═══════════╡
# │ 241890000 ┆ 53520     │
# │ 273318510 ┆ 51421     │
# │ 477887800 ┆ 44859     │
# │ 636018135 ┆ 44512     │
# │ 259490000 ┆ 43748     │
# │ …         ┆ …         │
# │ 265786030 ┆ 1         │
# │ 257030140 ┆ 1         │
# │ 205423000 ┆ 1         │
# │ 219004432 ┆ 1         │
# │ 246474000 ┆ 1         │
# └───────────┴───────────┘

# %%
#get count of rows per ship type
vessel_counts_st = (
    df.group_by(["Ship type"])
      .agg(pl.len().alias("row_count"))
      .sort("row_count", descending=True)
)

print(vessel_counts_st)
# Out:
# shape: (5, 2)
# ┌───────────┬───────────┐
# │ Ship type ┆ row_count │
# │ ---       ┆ ---       │
# │ str       ┆ u32       │
# ╞═══════════╪═══════════╡
# │ Cargo     ┆ 4236375   │
# │ Fishing   ┆ 3747052   │
# │ Passenger ┆ 2421880   │
# │ Tanker    ┆ 2010873   │
# │ Tug       ┆ 636290    │
# └───────────┴───────────┘

# %%
size = len(df)
print(f"""Dataset size: {size} rows \n
    Number of vessels in dataset: {len(df['MMSI'].unique())}\n
    Max rows for a single vessel: {vessel_counts[0, 'row_count']}\n
    Median rows per vessel: {vessel_counts['row_count'].median()}\n
    Mean rows per vessel: {vessel_counts['row_count'].mean()}\n
    number of vessels with more than {60*24} rows: {(vessel_counts['row_count'] > 60*24).sum()}\n
    number of vessels with under {24*6} row: {(vessel_counts['row_count'] < 24*6).sum()}""")
# Out:
# Dataset size: 13052470 rows
#
#     Number of vessels in dataset: 2029
#
#     Max rows for a single vessel: 53520
#
#     Median rows per vessel: 2346.0
#
#     Mean rows per vessel: 6432.957121734845
#
#     number of vessels with more than 1440 rows: 1188
#
#     number of vessels with under 144 row: 292

# %%
## percentage of null values per column
for col in df.columns:
    n = len(df)
    null_count = df[col].is_null().sum() / n * 100
    unknown_count = ((df[col].cast(pl.Utf8) == "Unknown").sum() + (df[col].cast(pl.Utf8) == "Unknown value").sum()) / n * 100
    undefined_count = (df[col].cast(pl.Utf8) == "Undefined").sum() / n * 100
    total_pct = null_count + unknown_count + undefined_count
    print(f"\n{col}: \n{null_count:.2f}% null, \n{unknown_count:.2f}% unknown, \n{undefined_count:.2f}% undefined, \n{total_pct:.2f}% total missing/unknown/undefined")
# Out:
# # Timestamp:
# 0.00% null,
# 0.00% unknown,
# 0.00% undefined,
# 0.00% total missing/unknown/undefined
#
# Type of mobile:
# 0.00% null,
# 0.00% unknown,
# 0.00% undefined,
# 0.00% total missing/unknown/undefined
#
# MMSI:
# 0.00% null,
# 0.00% unknown,
# 0.00% undefined,
# 0.00% total missing/unknown/undefined
#
# Latitude:
# 0.00% null,
# 0.00% unknown,
# 0.00% undefined,
# 0.00% total missing/unknown/undefined
#
# Longitude:
# 0.00% null,
# 0.00% unknown,
# 0.00% undefined,
# 0.00% total missing/unknown/undefined
#
# Navigational status:
# 0.00% null,
# 5.60% unknown,
# 0.00% undefined,
# 5.60% total missing/unknown/undefined
#
# ROT:
# 15.47% null,
# 0.00% unknown,
# 0.00% undefined,
# 15.47% total missing/unknown/undefined
#
# SOG:
# 0.17% null,
# 0.00% unknown,
# 0.00% undefined,
# 0.17% total missing/unknown/undefined
#
# COG:
# 4.43% null,
# 0.00% unknown,
# 0.00% undefined,
# 4.43% total missing/unknown/undefined
#
# Heading:
# 8.25% null,
# 0.00% unknown,
# 0.00% undefined,
# 8.25% total missing/unknown/undefined
#
# IMO:
# 0.00% null,
# 26.96% unknown,
# 0.00% undefined,
# 26.96% total missing/unknown/undefined
#
# Callsign:
# 0.00% null,
# 0.26% unknown,
# 0.00% undefined,
# 0.26% total missing/unknown/undefined
#
# Name:
# 0.00% null,
# 0.00% unknown,
# 0.00% undefined,
# 0.00% total missing/unknown/undefined
#
# Ship type:
# 0.00% null,
# 0.00% unknown,
# 0.00% undefined,
# 0.00% total missing/unknown/undefined
#
# Cargo type:
# 77.67% null,
# 0.00% unknown,
# 0.00% undefined,
# 77.67% total missing/unknown/undefined
#
# Width:
# 1.30% null,
# 0.00% unknown,
# 0.00% undefined,
# 1.30% total missing/unknown/undefined
#
# Length:
# 1.29% null,
# 0.00% unknown,
# 0.00% undefined,
# 1.29% total missing/unknown/undefined
#
# Type of position fixing device:
# 0.00% null,
# 0.00% unknown,
# 3.23% undefined,
# 3.23% total missing/unknown/undefined
#
# Draught:
# 16.46% null,
# 0.00% unknown,
# 0.00% undefined,
# 16.46% total missing/unknown/undefined
#
# Destination:
# 0.00% null,
# 14.29% unknown,
# 0.00% undefined,
# 14.29% total missing/unknown/undefined
#
# ETA:
# 24.23% null,
# 0.00% unknown,
# 0.00% undefined,
# 24.23% total missing/unknown/undefined
#
# Data source type:
# 0.00% null,
# 0.00% unknown,
# 0.00% undefined,
# 0.00% total missing/unknown/undefined
#
# A:
# 1.40% null,
# 0.00% unknown,
# 0.00% undefined,
# 1.40% total missing/unknown/undefined
#
# B:
# 1.82% null,
# 0.00% unknown,
# 0.00% undefined,
# 1.82% total missing/unknown/undefined
#
# C:
# 1.61% null,
# 0.00% unknown,
# 0.00% undefined,
# 1.61% total missing/unknown/undefined
#
# D:
# 2.18% null,
# 0.00% unknown,
# 0.00% undefined,
# 2.18% total missing/unknown/undefined

# %%
count = df["MMSI"].value_counts()
print(count)
# Out:
# shape: (1_478, 2)
# ┌───────────┬───────┐
# │ MMSI      ┆ count │
# │ ---       ┆ ---   │
# │ i64       ┆ u32   │
# ╞═══════════╪═══════╡
# │ 245086000 ┆ 11613 │
# │ 266254000 ┆ 1262  │
# │ 245286000 ┆ 15824 │
# │ 266160000 ┆ 2261  │
# │ 219009229 ┆ 27279 │
# │ …         ┆ …     │
# │ 258809000 ┆ 929   │
# │ 265547210 ┆ 29    │
# │ 219003383 ┆ 731   │
# │ 219005511 ┆ 17926 │
# │ 212376000 ┆ 10317 │
# └───────────┴───────┘

# %%
count = df["Navigational status"].value_counts().sort("count", descending=True)
print(count)
# Out:
# shape: (13, 2)
# ┌─────────────────────────────────┬─────────┐
# │ Navigational status             ┆ count   │
# │ ---                             ┆ ---     │
# │ str                             ┆ u32     │
# ╞═════════════════════════════════╪═════════╡
# │ Under way using engine          ┆ 7757129 │
# │ Engaged in fishing              ┆ 1766616 │
# │ Unknown value                   ┆ 761532  │
# │ Moored                          ┆ 224800  │
# │ Restricted maneuverability      ┆ 177749  │
# │ …                               ┆ …       │
# │ Reserved for future amendment … ┆ 36743   │
# │ Power-driven vessel towing ast… ┆ 25459   │
# │ Power-driven vessel pushing ah… ┆ 21522   │
# │ Reserved for future use         ┆ 6523    │
# │ Not under command               ┆ 3050    │
# └─────────────────────────────────┴─────────┘
