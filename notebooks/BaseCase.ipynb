# %%
import pandas as pd
import sklearn.metrics as metrics
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))
from fleetsense.features.data_loader import train_test_split_random, get_dataset
from fleetsense.model.base_model import train_baseline

# %%
df = get_dataset()
df[:10]

# %%
feature_groups = [
    "sog_p10",
    "sog_median",
    "frac_time_slow",
    "frac_time_fast",
    "heading_cog_diff_mean",
    "fishing_ratio",
    "anchor_ratio",
    "underway_engine_ratio",
    "moored_ratio",
    "length",
    "width",
    "max_draught",
    "draught_variability",
    "length_beam_ratio",
    "draught_length_ratio",
    "bbox_area",
    "mean_ping_interval_seconds",
]
X_train, X_test, y_train, y_test = train_test_split_random(df)

# %%
model = train_baseline(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
report = metrics.classification_report(y_test, y_pred)
print(report)

# %%
importances = model.feature_importances_

feat_importance = pd.Series(importances, index=feature_groups).sort_values(ascending=False)
print(feat_importance)
